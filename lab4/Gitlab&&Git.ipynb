# %% [markdown]
# **Gitlab & Git**

# %% [markdown]
# ![e3756280-e50c-11e9-877f-24272543fd9c.png](data:image/png;base64,...)

# %% [markdown]
# **Download git** :-  https://git-scm.com/

# %% [markdown]
# **Create gitlab account :-** https://gitlab.com/

# %% [markdown]
# **Connect your device with gitlab using ssh key**

# %% [markdown]
# https://docs.gitlab.com/user/ssh/

# %% [markdown]
# **Git Operations**

# %% [markdown]
# ![gitexplained-v0-0dxjidtrkste1.jpeg.webp](data:image/webp;base64,...)

# %% [markdown]
# # **Exercises :)**

# %% [markdown]
# 1- Create new project.
#
# 2- Download your project .
#
# 3- Add your friends to your new project .
#
# 4- Upload your work on your branch .
#
# 5- Merge your code and code of your friend in the same branch .
