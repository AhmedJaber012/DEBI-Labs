# %%
import pandas as pd

# %%
data = pd.read_table('Emploee table.txt', delim_whitespace=True)
# Out:
# C:\Users\AhmedJaber\AppData\Local\Temp\ipykernel_16404\3395093704.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_table is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_table('Emploee table.txt', delim_whitespace=True)

# %%
data
# Out:
#     emp_id first_name  Mid   last_name DEPT  phone   hire_data       job  \
# 0       10  CHRISTINE    I        HAAS  A00   3978  1965-01-01      PRES
# 1       20    MICHAEL    L    THOMPSON  B01   3476  1973-10-10   MANAGER
# 2       30      SALLY    A        KWAN  C01   4738  1975-04-05   MANAGER
# 3       50       JOHN    B       GEYER  E01   6789  1949-08-17   MANAGER
# 4       60     IRVING    F       STERN  D11   6423  1973-09-14   MANAGER
# 5       70        EVA    D     PULASKI  D21   7831  1980-09-30   MANAGER
# 6       90     EILEEN    W   HENDERSON  E11   5498  1970-08-15   MANAGER
# 7      100   THEODORE    Q     SPENSER  E21    972  1980-06-19   MANAGER
# 8      110   VINCENZO    G   LUCCHESSI  A00   3490  1958-05-16  SALESREP
# 9      120       SEAN  NaN   O'CONNELL  A00   2167  1963-12-05     CLERK
# 10     130    DOLORES    M    QUINTANA  C01   4578  1971-07-28   ANALYST
# 11     140    HEATHER    A    NICHOLLS  C01   1793  1976-12-15   ANALYST
# ...

# %%
data.to_csv('Employee_table.csv', index=False)
