# %% [markdown]
# **Install pymongo**

# %%
# !python -m pip install "pymongo[srv]"
# Out:
# ...
#   Obtaining dependency information for pymongo[srv] from https://files.pythonhosted.org/packages/8e/04/dedff8a5a9539e5b6128d8d2458b9c0c83ebd38b43389620a0d97223f114/pymongo-4.15.5-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for dnspython<3.0.0,>=1.16.0 from https://files.pythonhosted.org/packages/ba/5a/18ad964b0086c6e62e2e7500f7edc89e3faa45033c71c1893d34eed2b2de/dnspython-2.8.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/331.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/331.1 kB ? eta -:--:--
#    ---- ---------------------------------- 41.0/331.1 kB 667.8 kB/s eta 0:00:01
#    ---- ---------------------------------- 41.0/331.1 kB 667.8 kB/s eta 0:00:01
#    ---- ---------------------------------- 41.0/331.1 kB 667.8 kB/s eta 0:00:01
#    --------- ----------------------------- 81.9/331.1 kB 512.0 kB/s eta 0:00:01
#    --------------- ---------------------- 133.1/331.1 kB 563.7 kB/s eta 0:00:01
# ...

# %% [markdown]
# **Conncetion details**

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from bson import ObjectId


uri = 'mongodb+srv://ai2614012_db_user:4AkcD45XE98NfhCi@cluster0.9qspcwe.mongodb.net/?appName=Cluster0'
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# SSL handshake failed: ac-0rzzrzk-shard-00-01.9qspcwe.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-0rzzrzk-shard-00-02.9qspcwe.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-0rzzrzk-shard-00-00.9qspcwe.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6956a8dd1c939ad86d3dc97d, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-0rzzrzk-shard-00-00.9qspcwe.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-0rzzrzk-shard-00-00.9qspcwe.mongod
# ...

# %% [markdown]
# **Creation of database and tables**

# %%
db = client["company_db"] # database
collection = db["employees"] # table name
collection
# Out:
# Collection(Database(MongoClient(host=['ac-dnjubv9-shard-00-02.pdudvsn.mongodb.net:27017', 'ac-dnjubv9-shard-00-00.pdudvsn.mongodb.net:27017', 'ac-dnjubv9-shard-00-01.pdudvsn.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-25uqzr-shard-0', tls=True, server_api=<pymongo.server_api.ServerApi object at 0x7b0a8266fb60>), 'company_db'), 'employees')

# %% [markdown]
# **1-Insertion**

# %%
collection.insert_one({"name": "omar", "age": 23})# insert one record
# Out:
# InsertOneResult(ObjectId('6945b363340b1d19a3e6c25e'), acknowledged=True)

# %%
collection.insert_many([{"name": "mohamed", "age": 23},{"name": "hussien", "age": 23}])# insert multiple records
# Out:
# InsertManyResult([ObjectId('6945b363340b1d19a3e6c25f'), ObjectId('6945b363340b1d19a3e6c260')], acknowledged=True)

# %% [markdown]
# **2-Find Employee**

# %%
collection.find_one({"name": "Ahmed"}) # fliter by name u can define what you want
# Out:
# {'_id': ObjectId('6945a944340b1d19a3e6c252'), 'name': 'Ahmed', 'age': 26}

# %%
doc = collection.find_one({'_id': ObjectId("6945a890340b1d19a3e6c251")}) # search by id
print(doc)
# Out:
# None

# %% [markdown]
# **Get All docs using Find Function**

# %%
all_docs = collection.find() # retreive list of map  key and value


for doc in all_docs:
    print(doc)
    #print(str(doc['_id']))
# Out:
# {'_id': ObjectId('6945a944340b1d19a3e6c252'), 'name': 'Ahmed', 'age': 26}
# {'_id': ObjectId('6945a94f340b1d19a3e6c253'), 'name': 'Ahmed', 'age': 26}
# {'_id': ObjectId('6945a95b340b1d19a3e6c254'), 'name': 'Ahmed', 'age': 26}
# {'_id': ObjectId('6945a979340b1d19a3e6c255'), 'name': 'Ahmed', 'age': 26}
# {'_id': ObjectId('6945adbb340b1d19a3e6c256'), 'name': 'omar', 'age': 23}
# {'_id': ObjectId('6945b229340b1d19a3e6c257'), 'name': 'mohamed', 'age': 23}
# {'_id': ObjectId('6945b229340b1d19a3e6c258'), 'name': 'hussien', 'age': 23}
# {'_id': ObjectId('6945b346340b1d19a3e6c25a'), 'name': 'omar', 'age': 23}
# {'_id': ObjectId('6945b346340b1d19a3e6c25b'), 'name': 'mohamed', 'age': 23}
# {'_id': ObjectId('6945b346340b1d19a3e6c25c'), 'name': 'hussien', 'age': 23}
# {'_id': ObjectId('6945b363340b1d19a3e6c25e'), 'name': 'omar', 'age': 23}
# {'_id': ObjectId('6945b363340b1d19a3e6c25f'), 'name': 'mohamed', 'age': 23}
# {'_id': ObjectId('6945b363340b1d19a3e6c260'), 'name': 'hussien', 'age': 23}

# %%
collection.count_documents({})# get number of record like count(*)
# Out:
# 13

# %% [markdown]
# **3-Deletion**

# %%
collection.delete_one({"_id": ObjectId("6945a944340b1d19a3e6c252")})
collection.count_documents({})# get number of record like count(*)
# Out:
# 12

# %% [markdown]
# **4-Update Record**

# %%
collection.update_one({"name": "hussienxx"}, {"$set": {"name": "hussienxx00000"}}) # search the update
# Out:
# UpdateResult({'n': 0, 'electionId': ObjectId('7fffffff000000000000002d'), 'opTime': {'ts': Timestamp(1766175833, 2), 't': 45}, 'nModified': 0, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1766175833, 2), 'signature': {'hash': b'\to\x9c\xc4\xabh1\x81K\xe6\x93\xfb\x0f\x99\xcdR*`\xe8\x80', 'keyId': 7525845883091419146}}, 'operationTime': Timestamp(1766175833, 2), 'updatedExisting': False}, acknowledged=True)

# %%
all_docs = collection.find() # retreive list of map  key and value


for doc in all_docs:
    print(doc)
    #print(str(doc['_id']))
# Out:
# {'_id': ObjectId('6945a94f340b1d19a3e6c253'), 'name': 'Ahmed', 'age': 26}
# {'_id': ObjectId('6945a95b340b1d19a3e6c254'), 'name': 'Ahmed', 'age': 26}
# {'_id': ObjectId('6945a979340b1d19a3e6c255'), 'name': 'Ahmed', 'age': 26}
# {'_id': ObjectId('6945adbb340b1d19a3e6c256'), 'name': 'omar', 'age': 23}
# {'_id': ObjectId('6945b229340b1d19a3e6c257'), 'name': 'mohamed', 'age': 23}
# {'_id': ObjectId('6945b229340b1d19a3e6c258'), 'name': 'hussienxx00000', 'age': 23}
# {'_id': ObjectId('6945b346340b1d19a3e6c25a'), 'name': 'omar', 'age': 23}
# {'_id': ObjectId('6945b346340b1d19a3e6c25b'), 'name': 'mohamed', 'age': 23}
# {'_id': ObjectId('6945b346340b1d19a3e6c25c'), 'name': 'hussien', 'age': 23}
# {'_id': ObjectId('6945b363340b1d19a3e6c25e'), 'name': 'omar', 'age': 23}
# {'_id': ObjectId('6945b363340b1d19a3e6c25f'), 'name': 'mohamed', 'age': 23}
# {'_id': ObjectId('6945b363340b1d19a3e6c260'), 'name': 'hussien', 'age': 23}
