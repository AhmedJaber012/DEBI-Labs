# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedJaber012/DEBI-Labs/blob/main/Assignments/lab5%20%26%206/pyspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://gitlab.com/ai2614012/debi-labs.git
# Out:
# Cloning into 'debi-labs'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 70 (delta 18), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (70/70), 7.85 MiB | 22.59 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# !python /content/debi-labs/lab6/'spark 1.py'
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/28 12:30:54 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 🚀 Spark SQL Started
# 📄 Source Data
# +--------------+-----------+------+----------------+-----+------------+
# |transaction_id|customer_id|amount|transaction_date| city|payment_type|
# +--------------+-----------+------+----------------+-----+------------+
# |             1|        101|   250|      2024-01-01|Cairo|      Credit|
# |             2|        102|   500|      2024-01-01| Giza|        Cash|
# |             3|        101|  1200|      2024-01-02|Cairo|      Credit|
# |             4|        103|    50|      2024-01-02| Alex|        Cash|
# ...
